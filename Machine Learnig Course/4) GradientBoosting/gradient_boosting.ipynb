# %% [markdown]
# # Gradient Descent
# La discesa del gradiente (o Gradient Descent) è un algoritmo di ottimizzazione che cerca di trovare il punto di minimo di una funzione (come la funzione di errore in un modello di machine learning) spostandosi iterativamente nella direzione del gradiente negativo, ovvero la direzione di massima discesa. Immagina di essere su una montagna nebbiosa e di voler trovare il punto più basso; la discesa del gradiente consiste nel fare un passo nella direzione più ripida che scende, ripetendo questo processo fino a raggiungere la valle. Il "gradiente" è il vettore che indica la direzione di massima crescita della funzione, e muovendosi nella direzione opposta si minimizza la funzione stessa

# %% [markdown]
# # scikit-learn GradientBoosting
# Libreria interna e didattica, utile per capirne il funzionamento e testare prototipi. Per un'implementazione production-ready passeremo a XGBoost / LightGBM / CatBoost.

# %%
from sklearn.datasets import make_classification, make_regression
import numpy as np
import matplotlib as plt

#creiamo dataset fittizio per classificazione
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1) #1000 campioni, 10 features di cui 5 informative e 5 inutili

#e per regressione
X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1) #1000 campioni, 10 features di cui 5 informative e 5 inutili

# %% [markdown]
# # GradintBoostClassifier - scikit-learn

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score

X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)

#create model

sgb = GradientBoostingClassifier()
accuracy_cross_array = cross_val_score(sgb, X, y, scoring='accuracy', cv = 10, n_jobs=-1, error_score='raise') #n_jobs specifica il numero di job in parallelo per la cross-validation, -1 indica di usare tutti i processori.
#error_score ci dice se sollevare o meno un errore se avviene durante la cross-validation
print(f'accuracy media: {np.mean(accuracy_cross_array):.3f}, std: {np.std(accuracy_cross_array):.3f}')
sgb = GradientBoostingClassifier()
sgb.fit(X, y)

#define features for test set 
row = [[2.56999479, -0.13019997, 3.16075093, -4.35936352, -1.61271951, -1.39352057, -2.48924933, -1.93094078, 3.26130366, 2.05692145]]

yhat = sgb.predict(row)
print(f'Prediciton: {yhat}') #ci dice 0/1 per la row in ingresso
# Out:
# accuracy media: 0.909, std: 0.032
# Prediciton: [1]

# %% [markdown]
# # GradintBoostRegressor - scikit-learn

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score

X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1)

#create model
sgb = GradientBoostingRegressor()
neg_mean_absolute_error_array = cross_val_score(sgb, X, y, scoring='neg_mean_absolute_error', cv = 10, n_jobs=-1, error_score='raise') #n_jobs specifica il numero di job in parallelo per la cross-validation, -1 indica di usare tutti i processori.
#error_score ci dice se sollevare o meno un errore se avviene durante la cross-validation
print(f'neg_mean_absolute_error media: {np.mean(neg_mean_absolute_error_array):.3f}, std: {np.std(neg_mean_absolute_error_array):.3f}')
sgb = GradientBoostingRegressor()
sgb.fit(X, y)

#define features for test set 
row = [[2.02220122, 0.31563495, 0.82797464, -0.30620401, 0.16003707, -1.44411381, 0.87616892, -0.50446586, 0.23009474, 0.76201118]]

yhat = sgb.predict(row)
print(f'Prediciton: {yhat[0]:.3f}') #ci dice valore continuo assegnato alla row in ingresso
# Out:
# neg_mean_absolute_error media: -12.165, std: 1.007
# Prediciton: -80.661

# %% [markdown]
# # HistGradientBoostingClassifier - scikit-learn (supera GradeintBoostlassifier)
# Invece di costruire gli alberi considerando tutti i possibili split continui per ogni feature discretizza le feature in istogrammi, ad esempio, viene eseguita una discretizzazione che trasforma gli input continui in buckets (es. 255 bucket, valori tra 0 e 30 --> bucket 1, da 31 a 60 --> bucket 2 ecc...)

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
model = HistGradientBoostingClassifier()
n_scores = cross_val_score(model, X, y, scoring='accuracy', cv=10, n_jobs=-1, error_score='raise')
print(f'accuracy media: {np.mean(n_scores):.3f}, std: {np.std(n_scores):.3f}')
# fit the model on the whole dataset
model = HistGradientBoostingClassifier()
model.fit(X, y)
# make a single prediction
row = [[2.56999479, -0.13019997, 3.16075093, -4.35936352, -1.61271951, -1.39352057, -2.48924933, -1.93094078, 3.26130366, 2.05692145]]
yhat = model.predict(row)
print('Prediction: %d' % yhat[0])
# Out:
# accuracy media: 0.927, std: 0.030
# Prediction: 1

# %% [markdown]
# # HistGradientBoostingRegressor - scikit-learn (supera GradientBoostRegressor)
# Invece di costruire gli alberi considerando tutti i possibili split continui per ogni feature discretizza le feature in istogrammi, ad esempio, viene eseguita una discretizzazione che trasforma gli input continui in buckets (es. 255 bucket, valori tra 0 e 30 --> bucket 1, da 31 a 60 --> bucket 2 ecc...)

# %%
from sklearn.ensemble import HistGradientBoostingRegressor

# define dataset
X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1)
# evaluate the model
model = HistGradientBoostingRegressor()
neg_mean_absolute_error_array = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=10, n_jobs=-1, error_score='raise')
print(f'neg_mean_squared_error: {np.mean(neg_mean_absolute_error_array):.3f}, std: {np.std(neg_mean_absolute_error_array):.3f}')
# fit the model on the whole dataset
model = HistGradientBoostingRegressor()
model.fit(X, y)
# make a single prediction
row = [[2.02220122, 0.31563495, 0.82797464, -0.30620401, 0.16003707, -1.44411381, 0.87616892, -0.50446586, 0.23009474, 0.76201118]]
yhat = model.predict(row)
print('Prediction: %.3f' % yhat[0])
# Out:
# neg_mean_squared_error: -12.924, std: 1.203
# Prediction: -77.837

# %% [markdown]
# # XGBoost (best)
# Si costruisce un albero decisionale iniziale.
# Si calcola l’errore residuo (residuo = valore reale − predizione).
# Si costruisce un nuovo albero che predice questi residui.
# Si sommano le predizioni di tutti gli alberi.
# Si ripete fino a che non si raggiunge un numero massimo di alberi o l’errore è sufficientemente basso.
#
# Molto robusto, spesso batte reti neurali su dati strutturati.

# %% [markdown]
# # XGBClassifier

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.datasets import make_classification, make_regression

parameter_grid = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [3, 4, 5, 6, 7, 8, 9 ,10],
    'learning_rate' : [0.001, 0.01, 0.05, 0.1, 0.2], 
    'subsample' : [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma':[0, 0.1, 0.3, 0.5, 1],
    'reg_alpha' : [0, 0.01, 0.1, 1],
    'reg_lambda' : [0.1, 1, 10]
}

X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
model = XGBClassifier()

random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=parameter_grid,
    cv=5,
    n_iter=30,
    scoring='f1', 
    n_jobs=-1
)

random_search.fit(X, y)
scores = cross_val_score(random_search.best_estimator_, X, y, scoring='accuracy', cv=10, n_jobs=-1, error_score='raise')
print(f'accuracy media: {np.mean(scores):.3f}, std: {np.std(scores):.3f}')

row = [[2.56999479, -0.13019997, 3.16075093, -4.35936352, -1.61271951, -1.39352057, -2.48924933, -1.93094078, 3.26130366, 2.05692145]]
yhat = random_search.best_estimator_.predict(row)
print(f'Prediciton: {yhat[0]}')
# Out:
# accuracy media: 0.935, std: 0.022
# Prediciton: 1

# %% [markdown]
# # XGBRegressor

# %%
from xgboost import XGBRegressor

parameter_grid = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [3, 4, 5, 6, 7, 8, 9 ,10],
    'learning_rate' : [0.001, 0.01, 0.05, 0.1, 0.2], 
    'subsample' : [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'reg_alpha' : [0, 0.01, 0.1, 1],
    'reg_lambda' : [0.1, 1, 10]
}


X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1)
model = XGBRegressor(objective='reg:squarederror')
random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions= parameter_grid, 
    cv=5, 
    n_iter=30, 
    scoring='neg_mean_absolute_error',
    n_jobs=-1
)
random_search.fit(X, y)
model = random_search.best_estimator_
scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=10, n_jobs=-1, error_score='raise')
print(f'neg_mean_absolute_error: {np.mean(scores):.3f}, std: {np.std(scores):.3f}')




row = [2.02220122, 0.31563495, 0.82797464, -0.30620401, 0.16003707, -1.44411381, 0.87616892, -0.50446586, 0.23009474, 0.76201118]
row = np.asarray(row).reshape((1, len(row)))

yhat = model.predict(row)
print(f'Prediciton: {yhat[0]}')
# Out:
# neg_mean_absolute_error: -12.068, std: 0.895
# Prediciton: -91.94134521484375

# %% [markdown]
# # LightGBM
# più veloce su dataset grandi, usa leaf-wise growth, gestisce meglio dataset enormi.

# %% [markdown]
# # LGBMClassifier

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import RandomizedSearchCV
import pandas as pd

parameter_grid = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [3, 4, 5, 6, 7, 8, 9 ,10],
    'learning_rate' : [0.001, 0.01, 0.05, 0.1, 0.2], 
    'subsample' : [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'reg_alpha' : [0, 0.01, 0.1, 1],
    'reg_lambda' : [0.1, 1, 10]
}

X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
model = LGBMClassifier()

random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=parameter_grid,
    cv=5,
    n_iter=30,
    scoring='f1', 
    n_jobs=-1
)

random_search.fit(X, y)
scores = cross_val_score(random_search.best_estimator_, X, y, scoring='accuracy', cv=10, n_jobs=-1, error_score='raise')
print(f'accuracy media: {np.mean(scores):.3f}, std: {np.std(scores):.3f}')

row = [2.56999479, -0.13019997, 3.16075093, -4.35936352, -1.61271951, -1.39352057, -2.48924933, -1.93094078, 3.26130366, 2.05692145]
rows = pd.DataFrame([row], columns=[f'feature{i}' for i in range(len(row))]) #come primo parametro passo i vari record. Se passo un array flat, ogni entry viene interpretata come una riga, quindi devo racchiudere row tra []
yhat = random_search.best_estimator_.predict(rows) #si aspetta array 2D perche oltre ai valori del record features vuole anche i nomi delle features
print(f'Prediciton: {yhat[0]}')
# Out:
# [LightGBM] [Info] Number of positive: 501, number of negative: 499
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000374 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 1000, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.501000 -> initscore=0.004000
# [LightGBM] [Info] Start training from score 0.004000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# accuracy media: 0.935, std: 0.030
# Prediciton: 1

# %% [markdown]
# # LGBMRegressor

# %%
from lightgbm import LGBMRegressor

parameter_grid = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate': [0.001, 0.01, 0.05, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'reg_alpha': [0, 0.01, 0.1, 1],
    'reg_lambda': [0.1, 1, 10]
}

X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1)
model = LGBMRegressor()
random_search = RandomizedSearchCV(estimator=model, param_distributions=parameter_grid, n_jobs=-1, n_iter=30, cv=5, scoring='neg_mean_absolute_error')
random_search.fit(X, y)
scores = cross_val_score(random_search.best_estimator_, X, y, scoring='neg_mean_absolute_error', cv=10, n_jobs=-1, error_score='raise')
print(f'neg_mean_absolute_error: {np.mean(scores):.3f}, std: {np.std(scores):.3f}')



row = [2.02220122, 0.31563495, 0.82797464, -0.30620401, 0.16003707, -1.44411381, 0.87616892, -0.50446586, 0.23009474, 0.76201118]
rows = pd.DataFrame([row], columns=[f'feature {i}' for i in range(len(row))])

yhat = random_search.best_estimator_.predict(rows)
print(f'Prediciton: {yhat[0]}')
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000483 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 1000, number of used features: 10
# [LightGBM] [Info] Start training from score 2.143243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# neg_mean_absolute_error: -10.288, std: 0.674
# Prediciton: -78.77327525648542

# %% [markdown]
# # CatBoost
# Ottimo su categorical features, riduce il bisogno di feature engineering (encoding).

# %% [markdown]
# # CatBoostClassifier

# %%
from catboost import CatBoostClassifier
parameter_grid = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [3, 4, 5, 6, 7, 8, 9 ,10],
    'learning_rate' : [0.001, 0.01, 0.05, 0.1, 0.2], 
    'subsample' : [0.6, 0.8, 1.0],
    'reg_lambda' : [0.1, 1, 10]
}

X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
model = CatBoostClassifier()

random_search = RandomizedSearchCV(
    estimator=model,
    param_distributions=parameter_grid,
    cv=5,
    n_iter=30,
    scoring='f1', 
    n_jobs=-1
) #non ho X e y perche la cross validation e la conseguente sceltra del modello non avvioene ora, bensi al momento del .fit()

random_search.fit(X, y)
scores = cross_val_score(random_search.best_estimator_, X, y, scoring='accuracy', cv=10, n_jobs=-1, error_score='raise')
print(f'accuracy media: {np.mean(scores):.3f}, std: {np.std(scores):.3f}')

row = [2.56999479, -0.13019997, 3.16075093, -4.35936352, -1.61271951, -1.39352057, -2.48924933, -1.93094078, 3.26130366, 2.05692145]
rows = pd.DataFrame([row], columns=[f'feature{i}' for i in range(len(row))]) #come primo parametro passo i vari record. Se passo un array flat, ogni entry viene interpretata come una riga, quindi devo racchiudere row tra []
yhat = random_search.best_estimator_.predict(rows) #si aspetta array 2D perche oltre ai valori del record features vuole anche i nomi delle features
print(f'Prediciton: {yhat[0]}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 22
#      11 model = CatBoostClassifier()
#      13 random_search = RandomizedSearchCV(
#      14     estimator=model,
#      15     param_distributions=parameter_grid,
#    (...)
#      19     n_jobs=-1
#      20 ) #non ho X e y perche la cross validation e la conseguente sceltra del modello non avvioene ora, bensi al momento del .fit()
# ---> 22 random_search.fit(X, y)
#      23 scores = cross_val_score(random_search.best_estimator_, X, y, scoring='accuracy', cv=10, n_jobs=-1, error_score='raise')
#      24 print(f'accuracy media: {np.mean(scores):.3f}, std: {np.std(scores):.3f}')
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1051, in BaseSearchCV.fit(self, X, y, **params)
#    1045     results = self._format_results(
#    1046         all_candidate_params, n_splits, all_out, all_more_results
#    1047     )
#    1049     return results
# -> 1051 self._run_search(evaluate_candidates)
#    1053 # multimetric is determined here because in the case of a callable
#    1054 # self.scoring the return type is only known after calling
#    1055 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1992, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1990 def _run_search(self, evaluate_candidates):
#    1991     """Search n_iter candidates from param_distributions"""
# -> 1992     evaluate_candidates(
#    1993         ParameterSampler(
#    1994             self.param_distributions, self.n_iter, random_state=self.random_state
#    1995         )
#    1996     )
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:997, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     989 if self.verbose > 0:
#     990     print(
#     991         "Fitting {0} folds for each of {1} candidates,"
#     992         " totalling {2} fits".format(
#     993             n_splits, n_candidates, n_candidates * n_splits
#     994         )
#     995     )
# --> 997 out = parallel(
#     998     delayed(_fit_and_score)(
#     999         clone(base_estimator),
#    1000         X,
#    1001         y,
#    1002         train=train,
#    1003         test=test,
#    1004         parameters=parameters,
#    1005         split_progress=(split_idx, n_splits),
#    1006         candidate_progress=(cand_idx, n_candidates),
#    1007         **fit_and_score_kwargs,
#    1008     )
#    1009     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#    1010         enumerate(candidate_params),
#    1011         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#    1012     )
#    1013 )
#    1015 if len(out) < 1:
#    1016     raise ValueError(
#    1017         "No fits were performed. "
#    1018         "Was the CV iterator empty? "
#    1019         "Were there no candidates?"
#    1020     )
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)
#      80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)
#    1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)
#    1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %% [markdown]
# # CatBoostRegressor

# %%
from catboost import CatBoostRegressor

X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1)
model = CatBoostRegressor()

parameter_grid = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [3, 4, 5, 6, 7, 8, 9 ,10],
    'learning_rate' : [0.001, 0.01, 0.05, 0.1, 0.2], 
    'subsample' : [0.6, 0.8, 1.0],
    'reg_lambda' : [0.1, 1, 10]
}

random_search = RandomizedSearchCV(estimator=model, param_distributions=parameter_grid, n_iter=30, n_jobs=-1, cv=5, scoring='neg_mean_absolute_error')

random_search.fit(X, y)

scores = cross_val_score(random_search.best_estimator_, X, y, scoring='neg_mean_absolute_error', n_jobs=-1, cv=5, error_score='raise')

print(f'neg_mean_absolute_error: {np.mean(scores):.3f}, std: {np.std(scores):.3f}')



row = [2.02220122, 0.31563495, 0.82797464, -0.30620401, 0.16003707, -1.44411381, 0.87616892, -0.50446586, 0.23009474, 0.76201118]
rows = pd.DataFrame([row], columns=[f'feature {i}' for i in range(len(row))])

yhat = random_search.best_estimator_.predict(rows)
print(f'Prediciton: {yhat[0]}')
# Out:
# 0:	learn: 125.3014818	total: 610us	remaining: 305ms
# 1:	learn: 121.5928773	total: 1.07ms	remaining: 266ms
# 2:	learn: 117.2640807	total: 1.45ms	remaining: 240ms
# 3:	learn: 113.1748953	total: 1.82ms	remaining: 225ms
# 4:	learn: 109.0544135	total: 2.2ms	remaining: 218ms
# 5:	learn: 105.0253948	total: 2.57ms	remaining: 212ms
# 6:	learn: 101.7136815	total: 2.89ms	remaining: 204ms
# 7:	learn: 98.8594437	total: 3.23ms	remaining: 199ms
# 8:	learn: 95.9428830	total: 3.61ms	remaining: 197ms
# 9:	learn: 92.9817714	total: 3.96ms	remaining: 194ms
# 10:	learn: 90.3419583	total: 4.33ms	remaining: 193ms
# 11:	learn: 87.5970002	total: 4.79ms	remaining: 195ms
# 12:	learn: 84.9336608	total: 5.22ms	remaining: 196ms
# 13:	learn: 82.4312382	total: 5.83ms	remaining: 202ms
# 14:	learn: 80.2208588	total: 6.23ms	remaining: 201ms
# 15:	learn: 77.9358243	total: 6.57ms	remaining: 199ms
# 16:	learn: 75.6937407	total: 6.91ms	remaining: 196ms
# 17:	learn: 73.4032702	total: 7.32ms	remaining: 196ms
# 18:	learn: 71.2860782	total: 7.71ms	remaining: 195ms
# 19:	learn: 69.2896689	total: 8.17ms	remaining: 196ms
# 20:	learn: 67.4414099	total: 8.55ms	remaining: 195ms
# 21:	learn: 65.6414851	total: 8.93ms	remaining: 194ms
# 22:	learn: 63.7409290	total: 9.29ms	remaining: 193ms
# 23:	learn: 62.1894155	total: 9.68ms	remaining: 192ms
# 24:	learn: 60.5087247	total: 10ms	remaining: 190ms
# 25:	learn: 58.8355804	total: 10.4ms	remaining: 189ms
# 26:	learn: 57.3698753	total: 10.8ms	remaining: 188ms
# 27:	learn: 55.9627183	total: 11.2ms	remaining: 188ms
# 28:	learn: 54.5795430	total: 11.6ms	remaining: 188ms
# 29:	learn: 53.3012363	total: 11.9ms	remaining: 187ms
# 30:	learn: 51.9347284	total: 12.3ms	remaining: 186ms
# 31:	learn: 50.6568846	total: 12.6ms	remaining: 184ms
# 32:	learn: 49.5337899	total: 13ms	remaining: 183ms
# 33:	learn: 48.3243445	total: 13.3ms	remaining: 182ms
# 34:	learn: 47.1226101	total: 13.7ms	remaining: 181ms
# 35:	learn: 46.0999204	total: 14ms	remaining: 181ms
# 36:	learn: 45.0362069	total: 14.4ms	remaining: 180ms
# 37:	learn: 43.9373403	total: 14.8ms	remaining: 180ms
# 38:	learn: 42.9056408	total: 15.2ms	remaining: 180ms
# 39:	learn: 41.9885382	total: 15.6ms	remaining: 179ms
# 40:	learn: 41.0097042	total: 15.9ms	remaining: 178ms
# 41:	learn: 40.4702629	total: 16.3ms	remaining: 178ms
# 42:	learn: 39.6069123	total: 16.7ms	remaining: 177ms
# 43:	learn: 38.8604591	total: 17.1ms	remaining: 177ms
# 44:	learn: 38.1899382	total: 17.4ms	remaining: 176ms
# 45:	learn: 37.4508457	total: 17.8ms	remaining: 176ms
# 46:	learn: 36.7331080	total: 18.3ms	remaining: 176ms
# 47:	learn: 36.0385511	total: 18.7ms	remaining: 176ms
# 48:	learn: 35.3432760	total: 19ms	remaining: 175ms
# 49:	learn: 34.7528086	total: 19.4ms	remaining: 174ms
# 50:	learn: 34.1260526	total: 19.7ms	remaining: 174ms
# 51:	learn: 33.6008337	total: 20.1ms	remaining: 173ms
# 52:	learn: 32.9865294	total: 20.5ms	remaining: 173ms
# 53:	learn: 32.4036561	total: 20.8ms	remaining: 172ms
# 54:	learn: 31.6892385	total: 21.3ms	remaining: 172ms
# 55:	learn: 31.2164681	total: 21.7ms	remaining: 172ms
# 56:	learn: 30.6677104	total: 22.1ms	remaining: 172ms
# 57:	learn: 30.1117561	total: 22.5ms	remaining: 171ms
# 58:	learn: 29.5675970	total: 22.8ms	remaining: 171ms
# 59:	learn: 29.0124499	total: 23.2ms	remaining: 170ms
# 60:	learn: 28.5045572	total: 23.5ms	remaining: 169ms
# 61:	learn: 28.0672246	total: 23.9ms	remaining: 169ms
# 62:	learn: 27.6449572	total: 24.3ms	remaining: 168ms
# 63:	learn: 27.2110097	total: 24.6ms	remaining: 168ms
# 64:	learn: 26.7870172	total: 25ms	remaining: 167ms
# 65:	learn: 26.3535091	total: 25.4ms	remaining: 167ms
# 66:	learn: 25.9909562	total: 25.8ms	remaining: 166ms
# 67:	learn: 25.5404429	total: 26.1ms	remaining: 166ms
# 68:	learn: 25.1483488	total: 26.5ms	remaining: 165ms
# 69:	learn: 24.7510382	total: 26.8ms	remaining: 165ms
# 70:	learn: 24.4155572	total: 27.2ms	remaining: 164ms
# 71:	learn: 24.0372542	total: 27.6ms	remaining: 164ms
# 72:	learn: 23.6306433	total: 28ms	remaining: 164ms
# 73:	learn: 23.2344691	total: 28.3ms	remaining: 163ms
# 74:	learn: 22.8504851	total: 28.7ms	remaining: 163ms
# 75:	learn: 22.5151140	total: 29.1ms	remaining: 162ms
# 76:	learn: 22.1685077	total: 29.4ms	remaining: 162ms
# 77:	learn: 21.8379525	total: 29.8ms	remaining: 161ms
# 78:	learn: 21.5166871	total: 30.1ms	remaining: 161ms
# 79:	learn: 21.1890741	total: 30.4ms	remaining: 160ms
# 80:	learn: 20.8783042	total: 30.7ms	remaining: 159ms
# 81:	learn: 20.5397740	total: 31.1ms	remaining: 159ms
# 82:	learn: 20.2337281	total: 31.5ms	remaining: 158ms
# 83:	learn: 19.9411880	total: 31.9ms	remaining: 158ms
# 84:	learn: 19.6307445	total: 32.4ms	remaining: 158ms
# 85:	learn: 19.4159853	total: 32.8ms	remaining: 158ms
# 86:	learn: 19.1578172	total: 33.3ms	remaining: 158ms
# 87:	learn: 18.8904915	total: 33.6ms	remaining: 157ms
# 88:	learn: 18.6012852	total: 34ms	remaining: 157ms
# 89:	learn: 18.3321798	total: 34.3ms	remaining: 156ms
# 90:	learn: 18.0821180	total: 34.7ms	remaining: 156ms
# 91:	learn: 17.8170637	total: 35ms	remaining: 155ms
# 92:	learn: 17.5679043	total: 35.4ms	remaining: 155ms
# 93:	learn: 17.3219118	total: 35.8ms	remaining: 155ms
# 94:	learn: 17.0522943	total: 36.2ms	remaining: 154ms
# 95:	learn: 16.8378420	total: 36.6ms	remaining: 154ms
# 96:	learn: 16.6236304	total: 36.9ms	remaining: 153ms
# 97:	learn: 16.4351410	total: 37.3ms	remaining: 153ms
# 98:	learn: 16.2190946	total: 37.6ms	remaining: 152ms
# 99:	learn: 16.0223019	total: 38ms	remaining: 152ms
# 100:	learn: 15.8378690	total: 38.4ms	remaining: 152ms
# 101:	learn: 15.6243749	total: 38.8ms	remaining: 151ms
# 102:	learn: 15.4027501	total: 39.2ms	remaining: 151ms
# 103:	learn: 15.2468963	total: 39.6ms	remaining: 151ms
# 104:	learn: 15.0700556	total: 39.9ms	remaining: 150ms
# 105:	learn: 14.8863772	total: 40.3ms	remaining: 150ms
# 106:	learn: 14.7060414	total: 40.6ms	remaining: 149ms
# 107:	learn: 14.5202668	total: 41ms	remaining: 149ms
# 108:	learn: 14.3599841	total: 41.3ms	remaining: 148ms
# 109:	learn: 14.1863289	total: 41.7ms	remaining: 148ms
# 110:	learn: 14.0110596	total: 42ms	remaining: 147ms
# 111:	learn: 13.8391935	total: 42.4ms	remaining: 147ms
# 112:	learn: 13.6867982	total: 42.8ms	remaining: 147ms
# 113:	learn: 13.5332478	total: 43.2ms	remaining: 146ms
# 114:	learn: 13.3818743	total: 43.5ms	remaining: 146ms
# 115:	learn: 13.2172287	total: 43.9ms	remaining: 145ms
# 116:	learn: 13.0454750	total: 44.3ms	remaining: 145ms
# 117:	learn: 12.9048458	total: 44.7ms	remaining: 145ms
# 118:	learn: 12.7643412	total: 45.1ms	remaining: 144ms
# 119:	learn: 12.5998462	total: 45.4ms	remaining: 144ms
# 120:	learn: 12.4266533	total: 45.9ms	remaining: 144ms
# 121:	learn: 12.3004811	total: 46.3ms	remaining: 143ms
# 122:	learn: 12.1599441	total: 46.7ms	remaining: 143ms
# 123:	learn: 12.0306848	total: 47ms	remaining: 143ms
# 124:	learn: 11.8943862	total: 47.4ms	remaining: 142ms
# 125:	learn: 11.7568413	total: 47.8ms	remaining: 142ms
# 126:	learn: 11.6276250	total: 48.1ms	remaining: 141ms
# 127:	learn: 11.4986725	total: 48.5ms	remaining: 141ms
# 128:	learn: 11.3523148	total: 48.8ms	remaining: 140ms
# 129:	learn: 11.2179829	total: 49.2ms	remaining: 140ms
# 130:	learn: 11.0993939	total: 49.6ms	remaining: 140ms
# 131:	learn: 10.9711004	total: 50ms	remaining: 139ms
# 132:	learn: 10.8528522	total: 50.3ms	remaining: 139ms
# 133:	learn: 10.7327193	total: 50.7ms	remaining: 138ms
# 134:	learn: 10.6177677	total: 51ms	remaining: 138ms
# 135:	learn: 10.5114131	total: 51.3ms	remaining: 137ms
# 136:	learn: 10.4230416	total: 51.7ms	remaining: 137ms
# 137:	learn: 10.3226087	total: 52ms	remaining: 136ms
# 138:	learn: 10.2131921	total: 52.4ms	remaining: 136ms
# 139:	learn: 10.1075404	total: 52.7ms	remaining: 136ms
# 140:	learn: 10.0102324	total: 53.1ms	remaining: 135ms
# 141:	learn: 9.9025109	total: 53.5ms	remaining: 135ms
# 142:	learn: 9.7990995	total: 53.9ms	remaining: 134ms
# 143:	learn: 9.6989793	total: 54.2ms	remaining: 134ms
# 144:	learn: 9.5997466	total: 54.6ms	remaining: 134ms
# 145:	learn: 9.5064046	total: 54.9ms	remaining: 133ms
# 146:	learn: 9.4081388	total: 55.2ms	remaining: 133ms
# 147:	learn: 9.3192626	total: 55.6ms	remaining: 132ms
# 148:	learn: 9.2270371	total: 55.9ms	remaining: 132ms
# 149:	learn: 9.1360042	total: 56.2ms	remaining: 131ms
# 150:	learn: 9.0551569	total: 56.7ms	remaining: 131ms
# 151:	learn: 8.9699786	total: 57ms	remaining: 131ms
# 152:	learn: 8.8852599	total: 57.4ms	remaining: 130ms
# 153:	learn: 8.8051100	total: 57.7ms	remaining: 130ms
# 154:	learn: 8.7213524	total: 58ms	remaining: 129ms
# 155:	learn: 8.6363200	total: 58.3ms	remaining: 129ms
# 156:	learn: 8.5623907	total: 58.7ms	remaining: 128ms
# 157:	learn: 8.4882778	total: 59ms	remaining: 128ms
# 158:	learn: 8.4116263	total: 59.4ms	remaining: 127ms
# 159:	learn: 8.3385008	total: 59.7ms	remaining: 127ms
# 160:	learn: 8.2660489	total: 60.2ms	remaining: 127ms
# 161:	learn: 8.1923001	total: 60.6ms	remaining: 127ms
# 162:	learn: 8.1252492	total: 61ms	remaining: 126ms
# 163:	learn: 8.0547754	total: 61.4ms	remaining: 126ms
# 164:	learn: 7.9852681	total: 61.8ms	remaining: 126ms
# 165:	learn: 7.9211517	total: 62.2ms	remaining: 125ms
# 166:	learn: 7.8529774	total: 62.6ms	remaining: 125ms
# 167:	learn: 7.7907922	total: 63ms	remaining: 124ms
# 168:	learn: 7.7325262	total: 63.4ms	remaining: 124ms
# 169:	learn: 7.6686124	total: 63.8ms	remaining: 124ms
# 170:	learn: 7.6112909	total: 64.2ms	remaining: 123ms
# 171:	learn: 7.5479758	total: 64.6ms	remaining: 123ms
# 172:	learn: 7.4894078	total: 64.9ms	remaining: 123ms
# 173:	learn: 7.4314327	total: 65.3ms	remaining: 122ms
# 174:	learn: 7.3752632	total: 65.6ms	remaining: 122ms
# 175:	learn: 7.3180764	total: 66ms	remaining: 121ms
# 176:	learn: 7.2625680	total: 66.4ms	remaining: 121ms
# 177:	learn: 7.2101089	total: 66.7ms	remaining: 121ms
# 178:	learn: 7.1592794	total: 67.1ms	remaining: 120ms
# 179:	learn: 7.1047972	total: 67.4ms	remaining: 120ms
# 180:	learn: 7.0579974	total: 67.8ms	remaining: 119ms
# 181:	learn: 7.0075962	total: 68.1ms	remaining: 119ms
# 182:	learn: 6.9595250	total: 68.5ms	remaining: 119ms
# 183:	learn: 6.9134855	total: 68.8ms	remaining: 118ms
# 184:	learn: 6.8656188	total: 69.2ms	remaining: 118ms
# 185:	learn: 6.8145219	total: 69.5ms	remaining: 117ms
# 186:	learn: 6.7665239	total: 69.9ms	remaining: 117ms
# 187:	learn: 6.7215555	total: 70.2ms	remaining: 116ms
# 188:	learn: 6.6781693	total: 70.6ms	remaining: 116ms
# 189:	learn: 6.6345203	total: 71ms	remaining: 116ms
# 190:	learn: 6.5880376	total: 71.4ms	remaining: 115ms
# 191:	learn: 6.5448394	total: 71.7ms	remaining: 115ms
# 192:	learn: 6.5047555	total: 72.1ms	remaining: 115ms
# 193:	learn: 6.4660175	total: 72.4ms	remaining: 114ms
# 194:	learn: 6.4273423	total: 72.8ms	remaining: 114ms
# 195:	learn: 6.3886137	total: 73.1ms	remaining: 113ms
# 196:	learn: 6.3514043	total: 73.5ms	remaining: 113ms
# 197:	learn: 6.3128500	total: 74ms	remaining: 113ms
# 198:	learn: 6.2750054	total: 74.4ms	remaining: 113ms
# 199:	learn: 6.2413916	total: 74.8ms	remaining: 112ms
# 200:	learn: 6.2083807	total: 75.1ms	remaining: 112ms
# 201:	learn: 6.1725052	total: 75.5ms	remaining: 111ms
# 202:	learn: 6.1380393	total: 75.8ms	remaining: 111ms
# 203:	learn: 6.1063552	total: 76.2ms	remaining: 111ms
# 204:	learn: 6.0729953	total: 76.5ms	remaining: 110ms
# 205:	learn: 6.0401757	total: 76.9ms	remaining: 110ms
# 206:	learn: 6.0120598	total: 77.2ms	remaining: 109ms
# 207:	learn: 5.9800302	total: 77.6ms	remaining: 109ms
# 208:	learn: 5.9513865	total: 77.9ms	remaining: 108ms
# 209:	learn: 5.9219507	total: 78.3ms	remaining: 108ms
# 210:	learn: 5.8957497	total: 78.6ms	remaining: 108ms
# 211:	learn: 5.8657808	total: 78.9ms	remaining: 107ms
# 212:	learn: 5.8360640	total: 79.3ms	remaining: 107ms
# 213:	learn: 5.8069175	total: 79.6ms	remaining: 106ms
# 214:	learn: 5.7797056	total: 80ms	remaining: 106ms
# 215:	learn: 5.7530675	total: 80.3ms	remaining: 106ms
# 216:	learn: 5.7265663	total: 80.7ms	remaining: 105ms
# 217:	learn: 5.7034972	total: 81.1ms	remaining: 105ms
# 218:	learn: 5.6771424	total: 81.4ms	remaining: 104ms
# 219:	learn: 5.6499616	total: 81.7ms	remaining: 104ms
# 220:	learn: 5.6262267	total: 82.1ms	remaining: 104ms
# 221:	learn: 5.6034575	total: 82.5ms	remaining: 103ms
# 222:	learn: 5.5791661	total: 82.8ms	remaining: 103ms
# 223:	learn: 5.5572601	total: 83.2ms	remaining: 102ms
# 224:	learn: 5.5320644	total: 83.5ms	remaining: 102ms
# 225:	learn: 5.5108636	total: 83.9ms	remaining: 102ms
# 226:	learn: 5.4908059	total: 84.3ms	remaining: 101ms
# 227:	learn: 5.4708915	total: 84.7ms	remaining: 101ms
# 228:	learn: 5.4480019	total: 85ms	remaining: 101ms
# 229:	learn: 5.4264135	total: 85.3ms	remaining: 100ms
# 230:	learn: 5.4068497	total: 85.7ms	remaining: 99.8ms
# 231:	learn: 5.3862825	total: 86ms	remaining: 99.3ms
# 232:	learn: 5.3681571	total: 86.3ms	remaining: 98.9ms
# 233:	learn: 5.3456467	total: 86.7ms	remaining: 98.5ms
# 234:	learn: 5.3268820	total: 87.1ms	remaining: 98.2ms
# 235:	learn: 5.3099099	total: 87.4ms	remaining: 97.8ms
# 236:	learn: 5.2908005	total: 87.9ms	remaining: 97.5ms
# 237:	learn: 5.2733437	total: 88.5ms	remaining: 97.4ms
# 238:	learn: 5.2561087	total: 88.8ms	remaining: 97ms
# 239:	learn: 5.2397854	total: 89.2ms	remaining: 96.6ms
# 240:	learn: 5.2223553	total: 89.6ms	remaining: 96.3ms
# 241:	learn: 5.2056483	total: 89.9ms	remaining: 95.9ms
# 242:	learn: 5.1894509	total: 90.3ms	remaining: 95.5ms
# 243:	learn: 5.1749865	total: 90.7ms	remaining: 95.1ms
# 244:	learn: 5.1537675	total: 91.1ms	remaining: 94.8ms
# 245:	learn: 5.1354152	total: 91.4ms	remaining: 94.4ms
# 246:	learn: 5.1206424	total: 91.7ms	remaining: 94ms
# 247:	learn: 5.1064584	total: 92.1ms	remaining: 93.6ms
# 248:	learn: 5.0930990	total: 92.5ms	remaining: 93.2ms
# 249:	learn: 5.0785107	total: 92.9ms	remaining: 92.9ms
# 250:	learn: 5.0624040	total: 93.3ms	remaining: 92.5ms
# 251:	learn: 5.0488120	total: 93.6ms	remaining: 92.2ms
# 252:	learn: 5.0315375	total: 94ms	remaining: 91.8ms
# 253:	learn: 5.0172566	total: 94.5ms	remaining: 91.6ms
# 254:	learn: 4.9993107	total: 94.9ms	remaining: 91.2ms
# 255:	learn: 4.9861409	total: 95.2ms	remaining: 90.8ms
# 256:	learn: 4.9621951	total: 95.6ms	remaining: 90.4ms
# 257:	learn: 4.9501326	total: 95.9ms	remaining: 90ms
# 258:	learn: 4.9307150	total: 96.3ms	remaining: 89.6ms
# 259:	learn: 4.9195382	total: 96.6ms	remaining: 89.2ms
# 260:	learn: 4.9056414	total: 97ms	remaining: 88.8ms
# 261:	learn: 4.8929024	total: 97.3ms	remaining: 88.4ms
# 262:	learn: 4.8747982	total: 97.7ms	remaining: 88ms
# 263:	learn: 4.8542222	total: 98.1ms	remaining: 87.7ms
# 264:	learn: 4.8436886	total: 98.4ms	remaining: 87.3ms
# 265:	learn: 4.8313411	total: 98.8ms	remaining: 86.9ms
# 266:	learn: 4.8182152	total: 99.1ms	remaining: 86.5ms
# 267:	learn: 4.8060277	total: 99.4ms	remaining: 86.1ms
# 268:	learn: 4.7944173	total: 99.8ms	remaining: 85.7ms
# 269:	learn: 4.7786437	total: 100ms	remaining: 85.3ms
# 270:	learn: 4.7602597	total: 100ms	remaining: 84.9ms
# 271:	learn: 4.7484488	total: 101ms	remaining: 84.5ms
# 272:	learn: 4.7372011	total: 101ms	remaining: 84.1ms
# 273:	learn: 4.7236977	total: 102ms	remaining: 83.8ms
# 274:	learn: 4.7128962	total: 102ms	remaining: 83.4ms
# 275:	learn: 4.7026934	total: 102ms	remaining: 83ms
# 276:	learn: 4.6923860	total: 103ms	remaining: 82.7ms
# 277:	learn: 4.6807834	total: 103ms	remaining: 82.3ms
# 278:	learn: 4.6707825	total: 103ms	remaining: 81.9ms
# 279:	learn: 4.6601957	total: 104ms	remaining: 81.5ms
# 280:	learn: 4.6435026	total: 104ms	remaining: 81.1ms
# 281:	learn: 4.6313090	total: 104ms	remaining: 80.8ms
# 282:	learn: 4.6225966	total: 105ms	remaining: 80.5ms
# 283:	learn: 4.6135933	total: 105ms	remaining: 80.1ms
# 284:	learn: 4.5981220	total: 106ms	remaining: 79.7ms
# 285:	learn: 4.5876397	total: 106ms	remaining: 79.3ms
# 286:	learn: 4.5768431	total: 106ms	remaining: 78.9ms
# 287:	learn: 4.5674481	total: 107ms	remaining: 78.5ms
# 288:	learn: 4.5546136	total: 107ms	remaining: 78.1ms
# 289:	learn: 4.5452976	total: 107ms	remaining: 77.7ms
# 290:	learn: 4.5346484	total: 108ms	remaining: 77.4ms
# 291:	learn: 4.5210831	total: 108ms	remaining: 77ms
# 292:	learn: 4.5126282	total: 108ms	remaining: 76.6ms
# 293:	learn: 4.5012144	total: 109ms	remaining: 76.2ms
# 294:	learn: 4.4931429	total: 109ms	remaining: 75.8ms
# 295:	learn: 4.4844514	total: 109ms	remaining: 75.4ms
# 296:	learn: 4.4761263	total: 110ms	remaining: 75ms
# 297:	learn: 4.4564850	total: 110ms	remaining: 74.7ms
# 298:	learn: 4.4488888	total: 110ms	remaining: 74.3ms
# 299:	learn: 4.4381204	total: 111ms	remaining: 73.9ms
# 300:	learn: 4.4301913	total: 111ms	remaining: 73.5ms
# 301:	learn: 4.4197809	total: 112ms	remaining: 73.1ms
# 302:	learn: 4.4097610	total: 112ms	remaining: 72.8ms
# 303:	learn: 4.3996944	total: 112ms	remaining: 72.4ms
# 304:	learn: 4.3887012	total: 113ms	remaining: 72ms
# 305:	learn: 4.3707382	total: 113ms	remaining: 71.6ms
# 306:	learn: 4.3602071	total: 113ms	remaining: 71.2ms
# 307:	learn: 4.3508181	total: 114ms	remaining: 70.8ms
# 308:	learn: 4.3428640	total: 114ms	remaining: 70.4ms
# 309:	learn: 4.3344513	total: 114ms	remaining: 70ms
# 310:	learn: 4.3158335	total: 115ms	remaining: 69.6ms
# 311:	learn: 4.3001664	total: 115ms	remaining: 69.3ms
# 312:	learn: 4.2923165	total: 115ms	remaining: 69ms
# 313:	learn: 4.2827103	total: 116ms	remaining: 68.7ms
# 314:	learn: 4.2701419	total: 116ms	remaining: 68.4ms
# 315:	learn: 4.2637335	total: 117ms	remaining: 68ms
# 316:	learn: 4.2543049	total: 117ms	remaining: 67.7ms
# 317:	learn: 4.2451488	total: 118ms	remaining: 67.3ms
# 318:	learn: 4.2342910	total: 118ms	remaining: 66.9ms
# 319:	learn: 4.2270633	total: 118ms	remaining: 66.5ms
# 320:	learn: 4.2202655	total: 119ms	remaining: 66.1ms
# 321:	learn: 4.2120726	total: 119ms	remaining: 65.8ms
# 322:	learn: 4.2060838	total: 119ms	remaining: 65.4ms
# 323:	learn: 4.1996381	total: 120ms	remaining: 65ms
# 324:	learn: 4.1882162	total: 120ms	remaining: 64.7ms
# 325:	learn: 4.1724859	total: 121ms	remaining: 64.3ms
# 326:	learn: 4.1637739	total: 121ms	remaining: 63.9ms
# 327:	learn: 4.1559748	total: 121ms	remaining: 63.6ms
# 328:	learn: 4.1461368	total: 122ms	remaining: 63.2ms
# 329:	learn: 4.1312294	total: 122ms	remaining: 62.8ms
# 330:	learn: 4.1159755	total: 122ms	remaining: 62.5ms
# 331:	learn: 4.1067221	total: 123ms	remaining: 62.1ms
# 332:	learn: 4.0982075	total: 123ms	remaining: 61.7ms
# 333:	learn: 4.0914729	total: 123ms	remaining: 61.3ms
# 334:	learn: 4.0849649	total: 124ms	remaining: 61ms
# 335:	learn: 4.0783766	total: 124ms	remaining: 60.6ms
# 336:	learn: 4.0683929	total: 124ms	remaining: 60.2ms
# 337:	learn: 4.0611189	total: 125ms	remaining: 59.8ms
# 338:	learn: 4.0458130	total: 125ms	remaining: 59.4ms
# 339:	learn: 4.0344245	total: 126ms	remaining: 59.1ms
# 340:	learn: 4.0288404	total: 126ms	remaining: 58.7ms
# 341:	learn: 4.0207179	total: 126ms	remaining: 58.3ms
# 342:	learn: 4.0138783	total: 127ms	remaining: 58ms
# 343:	learn: 4.0079644	total: 127ms	remaining: 57.6ms
# 344:	learn: 3.9999886	total: 127ms	remaining: 57.2ms
# 345:	learn: 3.9947765	total: 128ms	remaining: 56.8ms
# 346:	learn: 3.9876343	total: 128ms	remaining: 56.4ms
# 347:	learn: 3.9821282	total: 128ms	remaining: 56.1ms
# 348:	learn: 3.9760869	total: 129ms	remaining: 55.7ms
# 349:	learn: 3.9674802	total: 129ms	remaining: 55.3ms
# 350:	learn: 3.9536393	total: 129ms	remaining: 54.9ms
# 351:	learn: 3.9488491	total: 130ms	remaining: 54.6ms
# 352:	learn: 3.9411729	total: 130ms	remaining: 54.2ms
# 353:	learn: 3.9314777	total: 131ms	remaining: 53.8ms
# 354:	learn: 3.9244968	total: 131ms	remaining: 53.4ms
# 355:	learn: 3.9165390	total: 131ms	remaining: 53.1ms
# 356:	learn: 3.9108999	total: 132ms	remaining: 52.7ms
# 357:	learn: 3.9023383	total: 132ms	remaining: 52.3ms
# 358:	learn: 3.8901446	total: 132ms	remaining: 51.9ms
# 359:	learn: 3.8846254	total: 133ms	remaining: 51.6ms
# 360:	learn: 3.8775334	total: 133ms	remaining: 51.2ms
# 361:	learn: 3.8672573	total: 133ms	remaining: 50.8ms
# 362:	learn: 3.8602518	total: 134ms	remaining: 50.5ms
# 363:	learn: 3.8539513	total: 134ms	remaining: 50.1ms
# 364:	learn: 3.8487765	total: 134ms	remaining: 49.7ms
# 365:	learn: 3.8416120	total: 135ms	remaining: 49.3ms
# 366:	learn: 3.8332021	total: 135ms	remaining: 48.9ms
# 367:	learn: 3.8199721	total: 135ms	remaining: 48.6ms
# 368:	learn: 3.8149186	total: 136ms	remaining: 48.2ms
# 369:	learn: 3.8060122	total: 136ms	remaining: 47.9ms
# 370:	learn: 3.8001495	total: 137ms	remaining: 47.5ms
# 371:	learn: 3.7950507	total: 137ms	remaining: 47.1ms
# 372:	learn: 3.7876479	total: 137ms	remaining: 46.8ms
# 373:	learn: 3.7808084	total: 138ms	remaining: 46.4ms
# 374:	learn: 3.7685744	total: 138ms	remaining: 46ms
# 375:	learn: 3.7617156	total: 138ms	remaining: 45.6ms
# 376:	learn: 3.7554413	total: 139ms	remaining: 45.2ms
# 377:	learn: 3.7508000	total: 139ms	remaining: 44.9ms
# 378:	learn: 3.7383281	total: 139ms	remaining: 44.5ms
# 379:	learn: 3.7327186	total: 140ms	remaining: 44.1ms
# 380:	learn: 3.7257231	total: 140ms	remaining: 43.8ms
# 381:	learn: 3.7204008	total: 140ms	remaining: 43.4ms
# 382:	learn: 3.7153628	total: 141ms	remaining: 43ms
# 383:	learn: 3.7091660	total: 141ms	remaining: 42.7ms
# 384:	learn: 3.7049273	total: 142ms	remaining: 42.3ms
# 385:	learn: 3.6995322	total: 142ms	remaining: 41.9ms
# 386:	learn: 3.6875445	total: 142ms	remaining: 41.5ms
# 387:	learn: 3.6818275	total: 143ms	remaining: 41.2ms
# 388:	learn: 3.6756263	total: 143ms	remaining: 40.8ms
# 389:	learn: 3.6647246	total: 143ms	remaining: 40.5ms
# 390:	learn: 3.6592997	total: 144ms	remaining: 40.1ms
# 391:	learn: 3.6521473	total: 144ms	remaining: 39.7ms
# 392:	learn: 3.6443277	total: 145ms	remaining: 39.4ms
# 393:	learn: 3.6344724	total: 145ms	remaining: 39ms
# 394:	learn: 3.6290888	total: 145ms	remaining: 38.6ms
# 395:	learn: 3.6235867	total: 146ms	remaining: 38.2ms
# 396:	learn: 3.6155366	total: 146ms	remaining: 37.9ms
# 397:	learn: 3.6104244	total: 146ms	remaining: 37.5ms
# 398:	learn: 3.6023584	total: 147ms	remaining: 37.1ms
# 399:	learn: 3.5927913	total: 147ms	remaining: 36.8ms
# 400:	learn: 3.5884583	total: 147ms	remaining: 36.4ms
# 401:	learn: 3.5834319	total: 148ms	remaining: 36ms
# 402:	learn: 3.5773835	total: 148ms	remaining: 35.6ms
# 403:	learn: 3.5713461	total: 148ms	remaining: 35.3ms
# 404:	learn: 3.5654045	total: 149ms	remaining: 34.9ms
# 405:	learn: 3.5566620	total: 149ms	remaining: 34.5ms
# 406:	learn: 3.5484847	total: 149ms	remaining: 34.2ms
# 407:	learn: 3.5423134	total: 150ms	remaining: 33.8ms
# 408:	learn: 3.5357668	total: 150ms	remaining: 33.5ms
# 409:	learn: 3.5297010	total: 151ms	remaining: 33.1ms
# 410:	learn: 3.5237891	total: 151ms	remaining: 32.7ms
# 411:	learn: 3.5203683	total: 151ms	remaining: 32.3ms
# 412:	learn: 3.5147076	total: 152ms	remaining: 32ms
# 413:	learn: 3.5094537	total: 152ms	remaining: 31.6ms
# 414:	learn: 3.5033605	total: 152ms	remaining: 31.2ms
# 415:	learn: 3.4964539	total: 153ms	remaining: 30.8ms
# 416:	learn: 3.4920219	total: 153ms	remaining: 30.5ms
# 417:	learn: 3.4859433	total: 153ms	remaining: 30.1ms
# 418:	learn: 3.4820639	total: 154ms	remaining: 29.7ms
# 419:	learn: 3.4762454	total: 154ms	remaining: 29.4ms
# 420:	learn: 3.4724429	total: 155ms	remaining: 29ms
# 421:	learn: 3.4670867	total: 155ms	remaining: 28.6ms
# 422:	learn: 3.4618719	total: 155ms	remaining: 28.3ms
# 423:	learn: 3.4569123	total: 156ms	remaining: 27.9ms
# 424:	learn: 3.4511861	total: 156ms	remaining: 27.5ms
# 425:	learn: 3.4471661	total: 156ms	remaining: 27.1ms
# 426:	learn: 3.4392541	total: 157ms	remaining: 26.8ms
# 427:	learn: 3.4335834	total: 157ms	remaining: 26.4ms
# 428:	learn: 3.4292647	total: 157ms	remaining: 26ms
# 429:	learn: 3.4241995	total: 158ms	remaining: 25.7ms
# 430:	learn: 3.4173098	total: 158ms	remaining: 25.3ms
# 431:	learn: 3.4124262	total: 158ms	remaining: 24.9ms
# 432:	learn: 3.4071726	total: 159ms	remaining: 24.5ms
# 433:	learn: 3.4018220	total: 159ms	remaining: 24.2ms
# 434:	learn: 3.3924039	total: 159ms	remaining: 23.8ms
# 435:	learn: 3.3854520	total: 160ms	remaining: 23.4ms
# 436:	learn: 3.3801322	total: 160ms	remaining: 23.1ms
# 437:	learn: 3.3740657	total: 160ms	remaining: 22.7ms
# 438:	learn: 3.3675506	total: 161ms	remaining: 22.3ms
# 439:	learn: 3.3632037	total: 161ms	remaining: 22ms
# 440:	learn: 3.3578416	total: 161ms	remaining: 21.6ms
# 441:	learn: 3.3513988	total: 162ms	remaining: 21.2ms
# 442:	learn: 3.3464155	total: 162ms	remaining: 20.9ms
# 443:	learn: 3.3427635	total: 162ms	remaining: 20.5ms
# 444:	learn: 3.3377461	total: 163ms	remaining: 20.1ms
# 445:	learn: 3.3348251	total: 163ms	remaining: 19.8ms
# 446:	learn: 3.3303975	total: 163ms	remaining: 19.4ms
# 447:	learn: 3.3250163	total: 164ms	remaining: 19ms
# 448:	learn: 3.3207159	total: 164ms	remaining: 18.7ms
# 449:	learn: 3.3147057	total: 165ms	remaining: 18.3ms
# 450:	learn: 3.3095722	total: 165ms	remaining: 17.9ms
# 451:	learn: 3.3032007	total: 165ms	remaining: 17.6ms
# 452:	learn: 3.2970091	total: 166ms	remaining: 17.2ms
# 453:	learn: 3.2922011	total: 166ms	remaining: 16.8ms
# 454:	learn: 3.2860088	total: 166ms	remaining: 16.5ms
# 455:	learn: 3.2814413	total: 167ms	remaining: 16.1ms
# 456:	learn: 3.2749459	total: 167ms	remaining: 15.7ms
# 457:	learn: 3.2691806	total: 168ms	remaining: 15.4ms
# 458:	learn: 3.2638200	total: 168ms	remaining: 15ms
# 459:	learn: 3.2587114	total: 169ms	remaining: 14.7ms
# 460:	learn: 3.2529616	total: 169ms	remaining: 14.3ms
# 461:	learn: 3.2492718	total: 169ms	remaining: 13.9ms
# 462:	learn: 3.2463834	total: 170ms	remaining: 13.6ms
# 463:	learn: 3.2423603	total: 170ms	remaining: 13.2ms
# 464:	learn: 3.2372412	total: 170ms	remaining: 12.8ms
# 465:	learn: 3.2334878	total: 171ms	remaining: 12.4ms
# 466:	learn: 3.2293483	total: 171ms	remaining: 12.1ms
# 467:	learn: 3.2259827	total: 171ms	remaining: 11.7ms
# 468:	learn: 3.2217913	total: 172ms	remaining: 11.4ms
# 469:	learn: 3.2167234	total: 172ms	remaining: 11ms
# 470:	learn: 3.2111595	total: 172ms	remaining: 10.6ms
# 471:	learn: 3.2078153	total: 173ms	remaining: 10.3ms
# 472:	learn: 3.2042167	total: 173ms	remaining: 9.9ms
# 473:	learn: 3.1986481	total: 174ms	remaining: 9.53ms
# 474:	learn: 3.1932048	total: 174ms	remaining: 9.17ms
# 475:	learn: 3.1876050	total: 175ms	remaining: 8.8ms
# 476:	learn: 3.1835340	total: 175ms	remaining: 8.43ms
# 477:	learn: 3.1792036	total: 175ms	remaining: 8.06ms
# 478:	learn: 3.1759685	total: 176ms	remaining: 7.7ms
# 479:	learn: 3.1718768	total: 176ms	remaining: 7.33ms
# 480:	learn: 3.1689621	total: 176ms	remaining: 6.96ms
# 481:	learn: 3.1632912	total: 177ms	remaining: 6.6ms
# 482:	learn: 3.1579115	total: 177ms	remaining: 6.23ms
# 483:	learn: 3.1533574	total: 177ms	remaining: 5.87ms
# 484:	learn: 3.1497104	total: 178ms	remaining: 5.5ms
# 485:	learn: 3.1451426	total: 178ms	remaining: 5.13ms
# 486:	learn: 3.1417791	total: 179ms	remaining: 4.77ms
# 487:	learn: 3.1378267	total: 179ms	remaining: 4.4ms
# 488:	learn: 3.1329288	total: 179ms	remaining: 4.03ms
# 489:	learn: 3.1261311	total: 180ms	remaining: 3.67ms
# 490:	learn: 3.1221408	total: 180ms	remaining: 3.3ms
# 491:	learn: 3.1195033	total: 181ms	remaining: 2.94ms
# 492:	learn: 3.1161428	total: 181ms	remaining: 2.57ms
# 493:	learn: 3.1118570	total: 181ms	remaining: 2.2ms
# 494:	learn: 3.1073040	total: 182ms	remaining: 1.84ms
# 495:	learn: 3.1021979	total: 182ms	remaining: 1.47ms
# 496:	learn: 3.0986517	total: 183ms	remaining: 1.1ms
# 497:	learn: 3.0930402	total: 183ms	remaining: 734us
# 498:	learn: 3.0890479	total: 183ms	remaining: 367us
# 499:	learn: 3.0840202	total: 184ms	remaining: 0us
# neg_mean_absolute_error: -5.300, std: 0.539
# Prediciton: -91.06032426900047
